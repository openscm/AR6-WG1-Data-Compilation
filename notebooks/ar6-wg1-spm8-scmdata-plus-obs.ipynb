# %% [markdown]
# # AR6 WG1 - SPM.8 plus observations
#
# This notebook combines parts of **Figure SPM.8** and **Figure SPM.10** of the IPCC's *Working Group I contribution to the Sixth Assessment Report* ([AR6 WG1](https://www.ipcc.ch/assessment-report/ar6/)). It follows the work by Ed Hawkin's shown at [Climate Lab Book](http://www.climate-lab-book.ac.uk/2021/adding-observations/).
#
# The data supporting the SPM figure is published under a Creative Commons CC-BY license at
# the [Centre for Environmental Data Analyis (CEDA)](https://catalogue.ceda.ac.uk/uuid/ae4f1eb6fce24adcb92ddca1a7838a5c).
#
# This notebook uses a version of that data which was processed for interoperability with the format used by IPCC WG3, the so-called IAMC format.
# The notebook is available under an open-source [BSD-3 License](https://github.com/openscm/AR6-WG1-Data-Compilation/blob/main/LICENSE) in the [openscm/AR6-WG1-Data-Compilation](https://github.com/openscm/AR6-WG1-Data-Compilation) GitHub repository.
#
# The notebook uses the community Python package [scmdata](https://scmdata.readthedocs.io), which is designed to handle simple climate model data but generalises to handle all sorts of timeseries-based data including data in the IAMC format. While it is primarily a data handling package and not a plotting package, scmdata does offer some convenient plotting functions which we use in these notebooks alongside [seaborn](https://seaborn.pydata.org) and native [matplotlib](https://matplotlib.org/) as required.

# %%
import matplotlib.pyplot as plt
import pyam
import scmdata
import yaml

import utils

# %%
plt.rcParams["axes.xmargin"] = 0
plt.rcParams["figure.figsize"] = (12, 8)

# %%
with open("plotting.yaml") as fh:
    palette = yaml.safe_load(fh)["color"]["scenario"]
    
palette = {k: pyam.plotting.PYAM_COLORS[v] for k, v in palette.items()}
palette["historical"] = "black"
palette
# Out:
# {'SSP1-1.9': '#00a9cf',
#  'SSP1-2.6': '#003466',
#  'SSP2-4.5': '#f69320',
#  'SSP3-7.0': '#df0000',
#  'SSP5-8.5': '#980002',
#  'historical': 'black'}

# %%
input_file_spm8 = utils.DATA_DIR / "processed" / "fig-spm8" / "fig-spm8-timeseries.csv"
input_file_spm8
# Out:
# PosixPath('/Users/znicholls/Documents/AGCEC/MCastle/ar6-wg1-data-compilation-zn/data/processed/fig-spm8/fig-spm8-timeseries.csv')

# %%
data_spm8 = scmdata.ScmRun(str(input_file_spm8))
data_spm8.head()
# Out:
# time                                                                                                                            1950-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#                                                                                            Surface Air Temperature Change|Mean         NaN
#                                                                            historical K    Surface Air Temperature Change|5%     -0.060030
#                                                                                            Surface Air Temperature Change|95%     0.608546
#
# time                                                                                                                            1951-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#                                                                                            Surface Air Temperature Change|Mean         NaN
#                                                                            historical K    Surface Air Temperature Change|5%     -0.055686
#                                                                                            Surface Air Temperature Change|95%     0.525308
#
# time                                                                                                                            1952-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#                                                                                            Surface Air Temperature Change|Mean         NaN
#                                                                            historical K    Surface Air Temperature Change|5%     -0.042891
#                                                                                            Surface Air Temperature Change|95%     0.540725
#
# time                                                                                                                            1953-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#                                                                                            Surface Air Temperature Change|Mean         NaN
#                                                                            historical K    Surface Air Temperature Change|5%     -0.020530
#                                                                                            Surface Air Temperature Change|95%     0.535419
#
# time                                                                                                                            1954-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#                                                                                            Surface Air Temperature Change|Mean         NaN
#                                                                            historical K    Surface Air Temperature Change|5%     -0.127657
#                                                                                            Surface Air Temperature Change|95%     0.553914
#
# time                                                                                                                            1955-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#                                                                                            Surface Air Temperature Change|Mean         NaN
#                                                                            historical K    Surface Air Temperature Change|5%     -0.045436
#                                                                                            Surface Air Temperature Change|95%     0.541897
#
# time                                                                                                                            1956-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#                                                                                            Surface Air Temperature Change|Mean         NaN
#                                                                            historical K    Surface Air Temperature Change|5%     -0.122056
#                                                                                            Surface Air Temperature Change|95%     0.595489
#
# time                                                                                                                            1957-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#                                                                                            Surface Air Temperature Change|Mean         NaN
#                                                                            historical K    Surface Air Temperature Change|5%     -0.081519
#                                                                                            Surface Air Temperature Change|95%     0.572240
#
# time                                                                                                                            1958-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#                                                                                            Surface Air Temperature Change|Mean         NaN
#                                                                            historical K    Surface Air Temperature Change|5%     -0.035150
#                                                                                            Surface Air Temperature Change|95%     0.534191
#
# time                                                                                                                            1959-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#                                                                                            Surface Air Temperature Change|Mean         NaN
#                                                                            historical K    Surface Air Temperature Change|5%     -0.023537
#                                                                                            Surface Air Temperature Change|95%     0.555881
#
# time                                                                                                                            ...  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable                             ...
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%    ...
#                                                                                            Surface Air Temperature Change|95%   ...
#                                                                                            Surface Air Temperature Change|Mean  ...
#                                                                            historical K    Surface Air Temperature Change|5%    ...
#                                                                                            Surface Air Temperature Change|95%   ...
#
# time                                                                                                                            2090-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%      2.085346
#                                                                                            Surface Air Temperature Change|95%     3.415727
#                                                                                            Surface Air Temperature Change|Mean    2.650092
#                                                                            historical K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#
# time                                                                                                                            2091-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%      2.093935
#                                                                                            Surface Air Temperature Change|95%     3.435020
#                                                                                            Surface Air Temperature Change|Mean    2.664827
#                                                                            historical K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#
# time                                                                                                                            2092-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%      2.100788
#                                                                                            Surface Air Temperature Change|95%     3.453626
#                                                                                            Surface Air Temperature Change|Mean    2.675315
#                                                                            historical K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#
# time                                                                                                                            2093-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%      2.107396
#                                                                                            Surface Air Temperature Change|95%     3.471900
#                                                                                            Surface Air Temperature Change|Mean    2.686950
#                                                                            historical K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#
# time                                                                                                                            2094-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%      2.114528
#                                                                                            Surface Air Temperature Change|95%     3.487838
#                                                                                            Surface Air Temperature Change|Mean    2.698346
#                                                                            historical K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#
# time                                                                                                                            2095-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%      2.121174
#                                                                                            Surface Air Temperature Change|95%     3.504371
#                                                                                            Surface Air Temperature Change|Mean    2.709810
#                                                                            historical K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#
# time                                                                                                                            2096-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%      2.126581
#                                                                                            Surface Air Temperature Change|95%     3.520522
#                                                                                            Surface Air Temperature Change|Mean    2.721367
#                                                                            historical K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#
# time                                                                                                                            2097-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%      2.132023
#                                                                                            Surface Air Temperature Change|95%     3.536066
#                                                                                            Surface Air Temperature Change|Mean    2.730281
#                                                                            historical K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#
# time                                                                                                                            2098-01-01  \
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%      2.138236
#                                                                                            Surface Air Temperature Change|95%     3.550991
#                                                                                            Surface Air Temperature Change|Mean    2.739834
#                                                                            historical K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#
# time                                                                                                                            2099-01-01
# model         reference_period_end_year reference_period_start_year region scenario   unit variable
# Ch.4 Assessed 1900.0                    1850.0                      World  SSP2-4.5   K    Surface Air Temperature Change|5%      2.144144
#                                                                                            Surface Air Temperature Change|95%     3.565741
#                                                                                            Surface Air Temperature Change|Mean    2.748134
#                                                                            historical K    Surface Air Temperature Change|5%           NaN
#                                                                                            Surface Air Temperature Change|95%          NaN
#
# [5 rows x 150 columns]

# %%
input_file_spm10 = utils.DATA_DIR / "processed" / "fig-spm10" / "fig-spm10-timeseries.csv"
input_file_spm10
# Out:
# PosixPath('/Users/znicholls/Documents/AGCEC/MCastle/ar6-wg1-data-compilation-zn/data/processed/fig-spm10/fig-spm10-timeseries.csv')

# %%
data_spm10 = scmdata.ScmRun(str(input_file_spm10))
data_spm10.head()
# Out:
# time                                                                                                                                            1850-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2                    NaN
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean         NaN
#                                                                                                            Surface Air Temperature Change|5%           NaN
#                                                                                                            Surface Air Temperature Change|95%          NaN
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2                2.66825
#
# time                                                                                                                                            1851-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2                    NaN
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean         NaN
#                                                                                                            Surface Air Temperature Change|5%           NaN
#                                                                                                            Surface Air Temperature Change|95%          NaN
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2               5.355922
#
# time                                                                                                                                            1852-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2                    NaN
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean         NaN
#                                                                                                            Surface Air Temperature Change|5%           NaN
#                                                                                                            Surface Air Temperature Change|95%          NaN
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2               8.070161
#
# time                                                                                                                                            1853-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2                    NaN
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean         NaN
#                                                                                                            Surface Air Temperature Change|5%           NaN
#                                                                                                            Surface Air Temperature Change|95%          NaN
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2              10.811831
#
# time                                                                                                                                            1854-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2                    NaN
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean         NaN
#                                                                                                            Surface Air Temperature Change|5%           NaN
#                                                                                                            Surface Air Temperature Change|95%          NaN
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2              13.602929
#
# time                                                                                                                                            1855-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2                    NaN
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean         NaN
#                                                                                                            Surface Air Temperature Change|5%           NaN
#                                                                                                            Surface Air Temperature Change|95%          NaN
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2              16.408693
#
# time                                                                                                                                            1856-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2                    NaN
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean         NaN
#                                                                                                            Surface Air Temperature Change|5%           NaN
#                                                                                                            Surface Air Temperature Change|95%          NaN
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2              19.246167
#
# time                                                                                                                                            1857-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2                    NaN
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean         NaN
#                                                                                                            Surface Air Temperature Change|5%           NaN
#                                                                                                            Surface Air Temperature Change|95%          NaN
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2              22.107591
#
# time                                                                                                                                            1858-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2                    NaN
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean         NaN
#                                                                                                            Surface Air Temperature Change|5%           NaN
#                                                                                                            Surface Air Temperature Change|95%          NaN
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2              24.991498
#
# time                                                                                                                                            1859-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2                    NaN
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean         NaN
#                                                                                                            Surface Air Temperature Change|5%           NaN
#                                                                                                            Surface Air Temperature Change|95%          NaN
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2              27.903669
#
# time                                                                                                                                            ...  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable                             ...
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2             ...
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean  ...
#                                                                                                            Surface Air Temperature Change|5%    ...
#                                                                                                            Surface Air Temperature Change|95%   ...
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2             ...
#
# time                                                                                                                                             2041-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2             3564.490611
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean     1.790723
#                                                                                                            Surface Air Temperature Change|5%       1.498170
#                                                                                                            Surface Air Temperature Change|95%      2.142621
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2                     NaN
#
# time                                                                                                                                             2042-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2             3623.869799
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean     1.822819
#                                                                                                            Surface Air Temperature Change|5%       1.523257
#                                                                                                            Surface Air Temperature Change|95%      2.190322
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2                     NaN
#
# time                                                                                                                                             2043-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2             3683.689595
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean     1.851875
#                                                                                                            Surface Air Temperature Change|5%       1.547114
#                                                                                                            Surface Air Temperature Change|95%      2.232232
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2                     NaN
#
# time                                                                                                                                             2044-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2             3743.950000
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean     1.883212
#                                                                                                            Surface Air Temperature Change|5%       1.571088
#                                                                                                            Surface Air Temperature Change|95%      2.275408
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2                     NaN
#
# time                                                                                                                                             2045-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2             3804.651015
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean     1.916044
#                                                                                                            Surface Air Temperature Change|5%       1.595126
#                                                                                                            Surface Air Temperature Change|95%      2.318900
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2                     NaN
#
# time                                                                                                                                             2046-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2             3865.792638
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean     1.949608
#                                                                                                            Surface Air Temperature Change|5%       1.619938
#                                                                                                            Surface Air Temperature Change|95%      2.362132
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2                     NaN
#
# time                                                                                                                                             2047-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2             3927.374870
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean     1.981984
#                                                                                                            Surface Air Temperature Change|5%       1.644832
#                                                                                                            Surface Air Temperature Change|95%      2.405011
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2                     NaN
#
# time                                                                                                                                             2048-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2             3989.397711
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean     2.012857
#                                                                                                            Surface Air Temperature Change|5%       1.668511
#                                                                                                            Surface Air Temperature Change|95%      2.446367
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2                     NaN
#
# time                                                                                                                                             2049-01-01  \
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2             4051.861160
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean     2.041733
#                                                                                                            Surface Air Temperature Change|5%       1.693462
#                                                                                                            Surface Air Temperature Change|95%      2.488925
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2                     NaN
#
# time                                                                                                                                             2050-01-01
# model                        reference_period_end_year reference_period_start_year region scenario   unit  variable
# IAMs                         1850                      1850                        World  SSP3-7.0   GtCO2 Cumulative Emissions|CO2             4114.765219
# Ch.4 assessment              1900                      1850                        World  SSP3-7.0   K     Surface Air Temperature Change|Mean     2.076303
#                                                                                                            Surface Air Temperature Change|5%       1.716882
#                                                                                                            Surface Air Temperature Change|95%      2.533662
# Friedlingstein et al. (2020) 1850                      1850                        World  historical GtCO2 Cumulative Emissions|CO2                     NaN
#
# [5 rows x 201 columns]

# %% [markdown]
# To make the output format work smoothly with scmdata's `scmdata.ScmRun.plumeplot` method, we firstly split the percentile from the variable name.

# %%
data_spm8_unmangled = utils.unmangle_stats(data_spm8)
data_spm8_unmangled["quantile"] = data_spm8_unmangled["statistic"].apply(utils.convert_stats_to_quantile)
data_spm8_unmangled.head()
# Out:
# time                                                                                                                                          1950-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change         NaN
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change         NaN
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change   -0.060030
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change    0.608546
#
# time                                                                                                                                          1951-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change         NaN
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change         NaN
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change   -0.055686
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change    0.525308
#
# time                                                                                                                                          1952-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change         NaN
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change         NaN
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change   -0.042891
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change    0.540725
#
# time                                                                                                                                          1953-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change         NaN
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change         NaN
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change   -0.020530
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change    0.535419
#
# time                                                                                                                                          1954-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change         NaN
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change         NaN
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change   -0.127657
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change    0.553914
#
# time                                                                                                                                          1955-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change         NaN
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change         NaN
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change   -0.045436
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change    0.541897
#
# time                                                                                                                                          1956-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change         NaN
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change         NaN
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change   -0.122056
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change    0.595489
#
# time                                                                                                                                          1957-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change         NaN
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change         NaN
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change   -0.081519
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change    0.572240
#
# time                                                                                                                                          1958-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change         NaN
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change         NaN
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change   -0.035150
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change    0.534191
#
# time                                                                                                                                          1959-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change         NaN
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change         NaN
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change   -0.023537
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change    0.555881
#
# time                                                                                                                                          ...  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable                        ...
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change  ...
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change  ...
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change  ...
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change  ...
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change  ...
#
# time                                                                                                                                          2090-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change    2.085346
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change    3.415727
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change    2.650092
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change         NaN
#
# time                                                                                                                                          2091-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change    2.093935
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change    3.435020
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change    2.664827
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change         NaN
#
# time                                                                                                                                          2092-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change    2.100788
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change    3.453626
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change    2.675315
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change         NaN
#
# time                                                                                                                                          2093-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change    2.107396
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change    3.471900
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change    2.686950
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change         NaN
#
# time                                                                                                                                          2094-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change    2.114528
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change    3.487838
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change    2.698346
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change         NaN
#
# time                                                                                                                                          2095-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change    2.121174
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change    3.504371
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change    2.709810
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change         NaN
#
# time                                                                                                                                          2096-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change    2.126581
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change    3.520522
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change    2.721367
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change         NaN
#
# time                                                                                                                                          2097-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change    2.132023
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change    3.536066
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change    2.730281
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change         NaN
#
# time                                                                                                                                          2098-01-01  \
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change    2.138236
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change    3.550991
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change    2.739834
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change         NaN
#
# time                                                                                                                                          2099-01-01
# model         quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.4 Assessed 0.05     1900.0                    1850.0                      World  SSP2-4.5   5%        K    Surface Air Temperature Change    2.144144
#               0.95     1900.0                    1850.0                      World  SSP2-4.5   95%       K    Surface Air Temperature Change    3.565741
#               0.50     1900.0                    1850.0                      World  SSP2-4.5   Mean      K    Surface Air Temperature Change    2.748134
#               0.05     1900.0                    1850.0                      World  historical 5%        K    Surface Air Temperature Change         NaN
#               0.95     1900.0                    1850.0                      World  historical 95%       K    Surface Air Temperature Change         NaN
#
# [5 rows x 150 columns]

# %%
data_spm10_unmangled = utils.unmangle_stats(data_spm10.filter(model="Ch.2 assessment"))
data_spm10_unmangled["quantile"] = data_spm10_unmangled["statistic"].apply(utils.convert_stats_to_quantile)
data_spm10_unmangled.head()
# Out:
# time                                                                                                                                                          1850-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                 -0.058676
#                                                                                                                 Surface Air Temperature Change|Anthropogenic   -0.030000
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic   -0.038750
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic    0.003000
#
# time                                                                                                                                                          1851-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                  0.048824
#                                                                                                                 Surface Air Temperature Change|Anthropogenic   -0.028583
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic   -0.037417
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic    0.002167
#
# time                                                                                                                                                          1852-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                  0.078824
#                                                                                                                 Surface Air Temperature Change|Anthropogenic   -0.027167
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic   -0.036083
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic    0.001583
#
# time                                                                                                                                                          1853-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                  0.046324
#                                                                                                                 Surface Air Temperature Change|Anthropogenic   -0.025583
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic   -0.035083
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic    0.000250
#
# time                                                                                                                                                          1854-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                  0.048824
#                                                                                                                 Surface Air Temperature Change|Anthropogenic   -0.025000
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic   -0.034083
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic   -0.001333
#
# time                                                                                                                                                          1855-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                  0.048824
#                                                                                                                 Surface Air Temperature Change|Anthropogenic   -0.025000
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic   -0.033667
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic   -0.003333
#
# time                                                                                                                                                          1856-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                 -0.051176
#                                                                                                                 Surface Air Temperature Change|Anthropogenic   -0.024000
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic   -0.033000
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic   -0.005750
#
# time                                                                                                                                                          1857-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                 -0.146176
#                                                                                                                 Surface Air Temperature Change|Anthropogenic   -0.024000
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic   -0.032667
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic   -0.007750
#
# time                                                                                                                                                          1858-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                 -0.038676
#                                                                                                                 Surface Air Temperature Change|Anthropogenic   -0.023583
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic   -0.032000
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic   -0.009833
#
# time                                                                                                                                                          1859-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                  0.068824
#                                                                                                                 Surface Air Temperature Change|Anthropogenic   -0.023000
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic   -0.032000
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic   -0.011917
#
# time                                                                                                                                                          ...  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable                                      ...
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                ...
#                                                                                                                 Surface Air Temperature Change|Anthropogenic  ...
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic  ...
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic  ...
#
# time                                                                                                                                                          2041-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                       NaN
#                                                                                                                 Surface Air Temperature Change|Anthropogenic         NaN
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic         NaN
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic         NaN
#
# time                                                                                                                                                          2042-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                       NaN
#                                                                                                                 Surface Air Temperature Change|Anthropogenic         NaN
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic         NaN
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic         NaN
#
# time                                                                                                                                                          2043-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                       NaN
#                                                                                                                 Surface Air Temperature Change|Anthropogenic         NaN
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic         NaN
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic         NaN
#
# time                                                                                                                                                          2044-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                       NaN
#                                                                                                                 Surface Air Temperature Change|Anthropogenic         NaN
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic         NaN
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic         NaN
#
# time                                                                                                                                                          2045-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                       NaN
#                                                                                                                 Surface Air Temperature Change|Anthropogenic         NaN
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic         NaN
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic         NaN
#
# time                                                                                                                                                          2046-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                       NaN
#                                                                                                                 Surface Air Temperature Change|Anthropogenic         NaN
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic         NaN
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic         NaN
#
# time                                                                                                                                                          2047-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                       NaN
#                                                                                                                 Surface Air Temperature Change|Anthropogenic         NaN
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic         NaN
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic         NaN
#
# time                                                                                                                                                          2048-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                       NaN
#                                                                                                                 Surface Air Temperature Change|Anthropogenic         NaN
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic         NaN
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic         NaN
#
# time                                                                                                                                                          2049-01-01  \
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                       NaN
#                                                                                                                 Surface Air Temperature Change|Anthropogenic         NaN
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic         NaN
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic         NaN
#
# time                                                                                                                                                          2050-01-01
# model           quantile reference_period_end_year reference_period_start_year region scenario   statistic unit variable
# Ch.2 assessment 0.50     1900                      1850                        World  historical Mean      K    Surface Air Temperature Change                       NaN
#                                                                                                                 Surface Air Temperature Change|Anthropogenic         NaN
#                 0.05     1900                      1850                        World  historical 5%        K    Surface Air Temperature Change|Anthropogenic         NaN
#                 0.95     1900                      1850                        World  historical 95%       K    Surface Air Temperature Change|Anthropogenic         NaN
#
# [4 rows x 201 columns]

# %%
plt_years = range(1850, 2100 + 1)
# plt_years = range(1950, 2030 + 1)

pdf = (
    data_spm10_unmangled
    .append(data_spm8_unmangled.filter(variable="Surface Air Temperature Change"))
    .filter(year=plt_years)
)
pdf["source_variable"] = pdf["model"] + " - " + pdf["variable"]

dashes = {
    "Ch.2 assessment - Surface Air Temperature Change": "-",
    "Ch.2 assessment - Surface Air Temperature Change|Anthropogenic": "--",
    "Ch.4 Assessed - Surface Air Temperature Change": "-"
}

ax, lh = pdf.plumeplot(
    hue_var="scenario", hue_label="Scenario", palette=palette, 
    style_var="source_variable", style_label="Source - variable", dashes=dashes,
    pre_calculated=True,
    quantiles_plumes=[((0.05, 0.95), 0.1), ((0.5,), 1.0)],
)

# make the observed temperature line bigger
(
    pdf
    .filter(source_variable="Ch.2 assessment - Surface Air Temperature Change")
    .lineplot(linewidth=5, color="black", ax=ax, legend=False)
)
# Out:
# /Users/znicholls/miniconda3/envs/ar6-wg1-data-compilation-zn/lib/python3.7/site-packages/scmdata/plotting.py:252: UserWarning: Quantile 0.05 not available for historical Ch.2 assessment - Surface Air Temperature Change
#   qt, hue_value, style_value
# /Users/znicholls/miniconda3/envs/ar6-wg1-data-compilation-zn/lib/python3.7/site-packages/scmdata/plotting.py:252: UserWarning: Quantile 0.95 not available for historical Ch.2 assessment - Surface Air Temperature Change
#   qt, hue_value, style_value
# <AxesSubplot:xlabel='time', ylabel='K'>
